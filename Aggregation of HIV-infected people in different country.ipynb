# %%
import numpy as np
import hvplot.pandas
import hvplot as hv
import seaborn as sns
import matplotlib.pyplot as plt
import panel as pn
pn.extension()
import pandas as pd

df=pd.read_csv('index.csv',index_col=0)
df1=pd.read_csv('demographics.csv',index_col=0)

# %%
df
# Out:
#                                  place_id wikidata_id datacommons_id  \
# location_key
# AD            ChIJlfCemC71pRIRkn_qeNc-yQc        Q228    country/AND
# AE            ChIJvRKrsd9IXj4RpwoIwFYv0zM        Q878    country/ARE
# AF            ChIJbQL_-LZu0TgReNqWvg1GtfM        Q889    country/AFG
# AF_BAL        ChIJWZOescNSyzgRkmVJ8fmfR3k     Q121104            NaN
# AF_BAM        ChIJw-bKQwDr0jgRQiw8jHsQ-HI     Q171382            NaN
# ...                                   ...         ...            ...
# ZA_WC_DC3     ChIJK_tKPIMB0h0Ra5Do064SuR8    Q1899307            NaN
# ZA_WC_DC4     ChIJ-YctajEi1B0R80qCAelNcY0     Q220249            NaN
# ZA_WC_DC5     ChIJg-OB74w21R0RumMhJW3W6wE    Q1053888            NaN
# ZM            ChIJcQv8_KX0QBkRRT5Yfqz5n_E        Q953    country/ZMB
# ZW            ChIJYXGxBuekMRkR7r_LxV84wKE        Q954    country/ZWE
#
#              country_code          country_name subregion1_code  \
# location_key
# ...

# %%
df1
# Out:
#               population  population_male  population_female  \
# location_key
# AD               77265.0          58625.0            55581.0
# AE             9890400.0        6836349.0          3054051.0
# AF            38928341.0       19976265.0         18952076.0
# AF_BAL         1509183.0              NaN                NaN
# AF_BAM          495557.0              NaN                NaN
# ...                  ...              ...                ...
# ZA_WC_DC3       286786.0              NaN                NaN
# ZA_WC_DC4       611278.0              NaN                NaN
# ZA_WC_DC5        74247.0              NaN                NaN
# ZM            18383956.0        9103006.0          9280950.0
# ZW            14862927.0        7092010.0          7770917.0
#
#               population_rural  population_urban  population_largest_city  \
# location_key
# AD                      9269.0           67873.0                      NaN
# ...

# %%
#df.hvplot.bar('country_code', y = 'aggregation_leve')
df2 = df[['country_code', 'aggregation_level']]
df2
df2.hvplot.bar('country_code', y = 'aggregation_level', groupby= 'aggregation_level',width = 4000)
# Out:
# :DynamicMap   [aggregation_level]
#    :Bars   [country_code]   (aggregation_level)

# %%
df_merge=pd.merge(df,df1,on='location_key', right_on=None)

# %%
df_merge
# Out:
#                                  place_id wikidata_id datacommons_id  \
# location_key
# AD            ChIJlfCemC71pRIRkn_qeNc-yQc        Q228    country/AND
# AE            ChIJvRKrsd9IXj4RpwoIwFYv0zM        Q878    country/ARE
# AF            ChIJbQL_-LZu0TgReNqWvg1GtfM        Q889    country/AFG
# AF_BAL        ChIJWZOescNSyzgRkmVJ8fmfR3k     Q121104            NaN
# AF_BAM        ChIJw-bKQwDr0jgRQiw8jHsQ-HI     Q171382            NaN
# ...                                   ...         ...            ...
# ZA_WC_DC3     ChIJK_tKPIMB0h0Ra5Do064SuR8    Q1899307            NaN
# ZA_WC_DC4     ChIJ-YctajEi1B0R80qCAelNcY0     Q220249            NaN
# ZA_WC_DC5     ChIJg-OB74w21R0RumMhJW3W6wE    Q1053888            NaN
# ZM            ChIJcQv8_KX0QBkRRT5Yfqz5n_E        Q953    country/ZMB
# ZW            ChIJYXGxBuekMRkR7r_LxV84wKE        Q954    country/ZWE
#
#              country_code          country_name subregion1_code  \
# location_key
# ...

# %%
df3 = df_merge[['country_code', 'aggregation_level','population']]
df3
# Out:
#              country_code  aggregation_level  population
# location_key
# AD                     AD                  0     77265.0
# AE                     AE                  0   9890400.0
# AF                     AF                  0  38928341.0
# AF_BAL                 AF                  1   1509183.0
# AF_BAM                 AF                  1    495557.0
# ...                   ...                ...         ...
# ZA_WC_DC3              ZA                  2    286786.0
# ZA_WC_DC4              ZA                  2    611278.0
# ZA_WC_DC5              ZA                  2     74247.0
# ZM                     ZM                  0  18383956.0
# ZW                     ZW                  0  14862927.0
#
# [21689 rows x 3 columns]

# %%
df3.hvplot.bar('country_code', y = 'population', groupby= 'aggregation_level',width = 4000)
#sns.scatterplot(data =df3,x= 'aggregation_level',y= 'population', hue= 'country_code')
# Out:
# :DynamicMap   [aggregation_level]
#    :Bars   [country_code]   (population)

# %%
df3.hvplot.bar('location_key', y = 'population', groupby= 'country_code')
#sns.scatterplot(data =df3,x= 'aggregation_level',y= 'population', hue= 'country_code')
# Out:
# :DynamicMap   [country_code]
#    :Bars   [location_key]   (population)

# %%
df4=pd.read_csv('hiv-death-rates-by-age.csv')

# %%
df4
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Rate)  \
# 0                                                  0.50
# 1                                                  0.49
# 2                                                  0.46
# 3                                                  0.47
# 4                                                  0.52
# ...                                                 ...
# 6835                                             102.96
# 6836                                              86.07
# 6837                                              78.12
# ...

# %%
#df5 = df4.drop('Entity','Year')
#df4.drop(columns = ['Code','Year'],inplace = True)
#df5=df4.drop([0, 1])
df5=df4.drop(['Entity','Year'], axis=1)
df5
df5.to_csv('hiv-death-rates-by-age1.csv')
#df6=df5.to_csv(index=False)

# %%
df6=pd.read_csv('hiv-death-rates-by-age1.csv',index_col=1)
df6
# Out:
#       Unnamed: 0  Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Rate)  \
# Code
# AFG            0                                               0.50
# AFG            1                                               0.49
# AFG            2                                               0.46
# AFG            3                                               0.47
# AFG            4                                               0.52
# ...          ...                                                ...
# ZWE         6835                                             102.96
# ZWE         6836                                              86.07
# ZWE         6837                                              78.12
# ZWE         6838                                              68.92
# ZWE         6839                                              66.07
#
#       Deaths - HIV/AIDS - Sex: Both - Age: 70+ years (Rate)  \
# Code
# AFG                                                0.42
# ...

# %%
df7=df6.drop('Unnamed: 0',axis=1)

# %%
sns.clustermap(df7,z_score=1,cmap='bwr',center=3)
